# %%
pip install geopandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 3.9 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 9.3 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2
import geopandas as gpd
import json
geojson_file_path = r"/Users/username/Desktop/GeoJSON_2/Top_Foton_geojson/Top_Foton_point.geojson"
gdf = gpd.read_file(geojson_file_path)

# %%
print(gdf.columns)
# Out:
# Index(['fid', 'Hüquqi sahibin adı', 'Əmlakın adı (Çıxarış üzrə)', 'Layihə',
#        'Şəhər', 'Rayon', 'Küçə', 'Daşınmaz əmlakın növü',
#        'Daşınmaz əmlakın üzərində hüququn növü',
#        'Torpaq sahəsi üzərində hüququn növü',
#        'Daşınmaz əmlakın mülkiyyət növü', 'Torpaq sahəsinin mülkiyyət növü',
#        'Daşınmaz əmlakın ümumi sahəsi (m2)', 'Torpaq sahəsinin ölçüsü (ha)',
#        'Daşınmaz əmlakın reyestr nömrəsi', 'Qeydiyyat nömrəsi', 'Seriya RX №',
#        'Texniki Pasportun reyestr nömrəsi', 'Qeydiyyat tarixi',
#        'Torpaq/əmlak kompleksi sahəsinin kateqoriyası (məqsədli təyinatı)',
#        '1C üzrə xüsusi kod', 'Attachment (Çıxarış)',
#        'Attachment (Texniki pasport)', 'Koordinat (texniki pasport)',
#        'Kateqoriya', 'Subkateqoriya', 'İcarə üzrə operator', 'İcarə statusu',
#        'Əmlakın istifadə təyinatı', 'Balans Dəyəri',
#        'Prior year valuation results (2023)',
# ...

# %%
# Define the desired column order
column_order = ['fid', 'Ünvan', 'Daşınmaz əmlakın növü', '1C üzrə xüsusi kod',
    'Hüquqi sahibin adı', 'Kateqoriya', 'Subkateqoriya',
    'Əmlakın adı (Çıxarış üzrə)', 'Layihə', 'Rayon', 'Şəhər', 'Küçə',
    'Qiymətləndirmə üzrə kateqoriya', 'Balans Dəyəri', 'Təyinat',
    'İcarə statusu', 'İcarə üçün yararsızlıq səbəbi', 'Mülkiyyət Payı',
    'Status_x', 'Əmlakın istifadə təyinatı', 'İcarə üzrə operator',
    'Daşınmaz əmlakın üzərində hüququn növü',
    'Torpaq sahəsi üzərində hüququn növü',
    'Daşınmaz əmlakın mülkiyyət növü', 'Torpaq sahəsinin mülkiyyət növü',
    'Daşınmaz əmlakın ümumi sahəsi (m2)', 'İcarə sahəsi',
    'Torpaq sahəsinin ölçüsü (ha)', 'Daşınmaz əmlakın reyestr nömrəsi',
    'Qeydiyyat nömrəsi', 'Seriya RX №', 'Texniki Pasportun reyestr nömrəsi',
    'Qeydiyyat tarixi',
    'Torpaq/əmlak kompleksi sahəsinin kateqoriyası (məqsədli təyinatı)',
    'Torpaq icarəsinin başlama tarixi', 'Torpaq icarəsinin bitmə tarixi',
    'İcarə müddəti', 'Aylıq icarə haqqı', 'İcarəyə verən tərəf',
    'Attachment (Çıxarış)', 'Attachment (Texniki pasport)',
    'Attachment (Digər)', 'Koordinat (texniki pasport)',
    'Prior year valuation results (2023)',
    'Current year valuation results (2024)', 'Variance', 'Valuation method',
    'Notes', 'Faktiki torpaq sahəsi (ha)',
    'İcarəçinin fəaliyyət göstərdiyi biznes sahəsi',
    'Portfelə daxil olma tarixi', 'Strateji tövsiyyə',
    'Tövsiyyə edilən təyinat', 'Prioritetlik müddəti', 'Faza', 'Status_y',
    'İl', 'Rüb', 'Note', 'geometry']

# %%
gdf = gdf[column_order]

# %%
gdf.to_file("test.geojson", driver="GeoJSON", encoding='utf-8')

# %%
geojson_file_path = r"/Users/username/Desktop/GeoJSON_2/GIS_loc_2/Polygon_Data.geojson"
gdf_2 = gpd.read_file(geojson_file_path)

# %%
print(gdf_2.columns)
# Out:
# Index(['fid', 'Ünvan', 'Daşınmaz əmlakın növü', '1C üzrə xüsusi kod',
#        'Hüquqi sahibin adı', 'Kateqoriya', 'Subkateqoriya',
#        'Əmlakın adı (Çıxarış üzrə)', 'Layihə', 'Rayon', 'Şəhər', 'Küçə',
#        'Qiymətləndirmə üzrə kateqoriya', 'Balans Dəyəri', 'Təyinat',
#        'İcarə statusu', 'İcarə üçün yararsızlıq səbəbi', 'Mülkiyyət Payı',
#        'Status_x', 'Əmlakın istifadə təyinatı', 'İcarə üzrə operator',
#        'Daşınmaz əmlakın üzərində hüququn növü',
#        'Torpaq sahəsi üzərində hüququn növü',
#        'Daşınmaz əmlakın mülkiyyət növü', 'Torpaq sahəsinin mülkiyyət növü',
#        'Daşınmaz əmlakın ümumi sahəsi (m2)', 'İcarə sahəsi',
#        'Torpaq sahəsinin ölçüsü (ha)', 'Daşınmaz əmlakın reyestr nömrəsi',
#        'Qeydiyyat nömrəsi', 'Seriya RX №', 'Texniki Pasportun reyestr nömrəsi',
#        'Qeydiyyat tarixi',
#        'Torpaq/əmlak kompleksi sahəsinin kateqoriyası (məqsədli təyinatı)',
# ...

# %%
num_columns = gdf.shape[1]
print("Number of columns:", num_columns)
# Out:
# Number of columns: 60

# %%
num_columns = gdf_2.shape[1]
print("Number of columns:", num_columns)
# Out:
# Number of columns: 60
